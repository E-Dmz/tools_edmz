# %%
import sys

from pathlib import Path

sys.path = [str(Path.home() / "code" / "doumazane/bg-atlasapi"), # overrides pypi package
            str(Path.home() / "code" / "NicoKiaru/ABBA-Python"),
           ] + sys.path

# core dependencies
import os
import time

from bg_atlasapi import show_atlases
from bg_atlasapi import utils

from abba import Abba

# %% [markdown]
# ## Conventional way of loading an atlas from the bg-atlas API

# %%
abba = Abba("allen_mouse_25um_v1.2")
abba.show_bdv_ui()
# Out:
# 14:03:29.125 [main] DEBUG sc.fiji.bdvpg.scijava.services.SourceAndConverterService - Registering action entitled Plugins > BIOP > Atlas > Multi Image To Atlas > ABBA - Preferences from command ch.epfl.biop.atlas.aligner.command.ABBASetBDVPreferencesCommand sacs ignored
# 14:03:29.134 [main] DEBUG sc.fiji.bdvpg.scijava.services.SourceAndConverterService - Registering action entitled Add Metadata To Sources from command sc.fiji.bdvpg.scijava.command.source.AddMetadataCommand
# 14:03:29.135 [main] DEBUG sc.fiji.bdvpg.scijava.services.SourceAndConverterService - Registering action entitled Affine Transform Sources from command ch.epfl.biop.scijava.command.source.register.SourcesAffineTransformCommand
# ...

# %%
import sys

from pathlib import Path

sys.path = [str(Path.home() / "code" / "doumazane/bg-atlasapi"), # overrides pypi package
            str(Path.home() / "code" / "NicoKiaru/ABBA-Python"),
           ] + sys.path

# core dependencies
import os
import time

from bg_atlasapi import show_atlases
from bg_atlasapi import utils

from abba import Abba

abba = Abba("allen_mouse__25um_v1.2")
abba.show_bdv_ui()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_34705/2323422864.py in <module>
# ----> 1 abba = Abba("allen_mouse__25um_v1.2")
#
# ~/code/NicoKiaru/ABBA-Python/abba/Abba.py in __init__(self, atlas_name, ij, slicing_mode, headless)
#      86                 Abba.opened_atlases[atlas_name] = atlas
#      87             else:
# ---> 88                 bg_atlas = BrainGlobeAtlas(atlas_name)
#      89                 from abba.abba_private import AbbaAtlas  # delayed import because the jvm should be correctly
#      90                 # initialized
#
# ~/programs/miniconda3/envs/abba-brainglobe-deepslice/lib/python3.7/site-packages/bg_atlasapi/bg_atlas.py in __init__(self, atlas_name, brainglobe_dir, interm_download_dir, check_latest, config_dir)
#      76         if self.local_full_name is None:
#      77             if self.remote_version is None:
# ...

# %%
from bg_atlasapi import show_atlases
from bg_atlasapi import utils

# %%
abba = Abba("allen_mouse__25um_v1.2")
abba.show_bdv_ui()
# Out:
# 11:55:02.666 [main] DEBUG sc.fiji.bdvpg.scijava.services.SourceAndConverterService - Registering action entitled Plugins > BIOP > Atlas > Multi Image To Atlas > ABBA - Preferences from command ch.epfl.biop.atlas.aligner.command.ABBASetBDVPreferencesCommand sacs ignored
# 11:55:02.679 [main] DEBUG sc.fiji.bdvpg.scijava.services.SourceAndConverterService - Registering action entitled Add Metadata To Sources from command sc.fiji.bdvpg.scijava.command.source.AddMetadataCommand
# 11:55:02.680 [main] DEBUG sc.fiji.bdvpg.scijava.services.SourceAndConverterService - Registering action entitled Affine Transform Sources from command ch.epfl.biop.scijava.command.source.register.SourcesAffineTransformCommand
# ...
