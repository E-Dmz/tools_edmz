# %%
import pandas as pd

# %%
folder = "/home/etienne.doumazane/data/solisa/220607-otof-14m-fos"

# %%
import os

# %%
os.listdir(folder)
# Out:
# ['7wcells.feather',
#  '1kcells.feather',
#  '3kcells.feather',
#  '2kcells.feather',
#  '6wcells.feather',
#  '5wcells.feather']

# %%
fnames = ['6wcells.feather',
 '2kcells.feather',
 '5wcells.feather',
 '3kcells.feather',
 '1kcells.feather',
 '7wcells.feather']

# %%
paths = [os.path.join(folder, fname) for fname in fnames]

# %%
path = paths[0]

# %%
pd.read_feather(path)
# Out:
#             x     y     z  size       source          xt          yt  \
# 0        4002  3177     6    57  225077064.0  311.327848  311.707709
# 1        3986  2995     8    70  284823415.0  311.312985  299.066865
# 2        4016  3032     8   101  284947757.0  313.108491  301.738794
# 3        4032  3254     8    67  285014051.0  312.752067  317.080040
# 4        4033  3251     8    62  285018193.0  312.838319  316.877044
# ...       ...   ...   ...   ...          ...         ...         ...
# 1272325  4708   297  1052   132  135929126.0  333.304076   86.126790
# 1272326  4882  2458  1052   199  135948172.0  332.670810  238.663069
# 1272327  4170   110  1053    59  136946400.0  296.117324   69.917176
# 1272328  4645   285  1053    58  136993618.0  328.777650   84.864617
# 1272329  4653   292  1053   196  136994403.0  329.305026   85.396563
#
#                  zt  order         id  hemisphere  \
# 0         19.290712    178        281           0
# ...

# %%
for path in paths:
    pd.read_feather(path).to_csv(path + ".csv")

# %%
paths
# Out:
# ['/home/etienne.doumazane/data/solisa/220607-otof-14m-fos/6wcells.feather',
#  '/home/etienne.doumazane/data/solisa/220607-otof-14m-fos/2kcells.feather',
#  '/home/etienne.doumazane/data/solisa/220607-otof-14m-fos/5wcells.feather',
#  '/home/etienne.doumazane/data/solisa/220607-otof-14m-fos/3kcells.feather',
#  '/home/etienne.doumazane/data/solisa/220607-otof-14m-fos/1kcells.feather',
#  '/home/etienne.doumazane/data/solisa/220607-otof-14m-fos/7wcells.feather']
