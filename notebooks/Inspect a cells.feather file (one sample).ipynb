# %% [markdown]
# # Inspect at a `cells.feather` file (one sample)

# %% [markdown]
# - `Creation` = 2022_10_07
# - `Last modification` = 2022_10_07

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Opening the file

# %%
FPATH = "/home/etienne.doumazane/data/Alba/200316-81/cells.feather"
df = pd.read_feather(FPATH)
df
# Out:
#           x     y     z  size      source          xt          yt          zt  \
# 0      3215  3190    63   152   9840723.0  252.417411  311.154415    7.025416
# 1      2758  3015    67    56  15002249.0  216.549555  297.354154   11.607513
# 2      2058  2815    70   118  18837674.0  160.973055  282.263718   18.186485
# 3      2499  3146    71    85  20225798.0  196.350462  308.234519   12.046745
# 4      2404  2583    78   187   6006774.0  188.846829  263.822546   19.862904
# ...     ...   ...   ...   ...         ...         ...         ...         ...
# 45459  2989  2906  1928   720  19111106.0  241.001125  301.246624  300.103735
# 45460  3344  4589  1940    57   8798607.0  267.654416  422.508356  287.271656
# 45461  2135  5636  1979    65  16131788.0  165.716385  507.782585  300.758661
# 45462  3503  5334  1989    52  38127624.0  281.117839  481.403220  293.956547
# 45463  4108   808  2018    50  22769726.0  329.057548  139.281949  324.369881
#
#        order         id  hemisphere  \
# 0        332        442         255
# 1          0          0           0
# 2        385  312782560           0
# 3        333        434           0
# 4        306        965           0
# ...      ...        ...         ...
# 45459      0          0         255
# 45460    927        354         255
# 45461      0          0           0
# 45462    927        354         255
# 45463      0          0           0
#
#                                                     name  \
# 0               Retrosplenial area, dorsal part, layer 1
# 1                                               universe
# 2                                               No label
# 3             Retrosplenial area, dorsal part, layer 2/3
# 4      Retrosplenial area, lateral agranular part, la...
# ...                                                  ...
# 45459                                           universe
# 45460                                            Medulla
# 45461                                           universe
# 45462                                            Medulla
# 45463                                           universe
#
#                                                    color        volume
# 0      [0.10196078431372549, 0.6509803921568628, 0.59...     815281250
# 1                                        [0.0, 0.0, 0.0]  704492906250
# 2         [0.4392156862745098, 1.0, 0.44313725490196076]    1439937500
# 3      [0.10196078431372549, 0.6509803921568628, 0.59...     974046875
# 4      [0.10196078431372549, 0.6509803921568628, 0.59...     671468750
# ...                                                  ...           ...
# 45459                                    [0.0, 0.0, 0.0]  704492906250
# 45460       [1.0, 0.6078431372549019, 0.803921568627451]    8992203125
# 45461                                    [0.0, 0.0, 0.0]  704492906250
# 45462       [1.0, 0.6078431372549019, 0.803921568627451]    8992203125
# 45463                                    [0.0, 0.0, 0.0]  704492906250
#
# [45464 rows x 14 columns]

# %% [markdown]
# ## Hemispheres

# %%
'hemisphere' in df.columns
# Out:
# True

# %%
df.hemisphere.unique()
# Out:
# array([255,   0])

# %% [markdown]
# ##  Number of cells in sample

# %%
df.shape[0]
# Out:
# 45464

# %% [markdown]
# ## Distribution of cells across the large regions of the brain

# %%
df.groupby('name')['id'].count().sort_values(ascending=False)
# Out:
# name
# Primary somatosensory area, barrel field, layer 2/3    9546
# No label                                               4028
# Primary somatosensory area, barrel field, layer 6a     3404
# Primary somatosensory area, barrel field, layer 4      2493
# Secondary motor area, layer 5                          2029
#                                                        ...
# Interpeduncular nucleus                                   1
# Interfascicular nucleus raphe                             1
# Infralimbic area, layer 1                                 1
# Gustatory areas, layer 5                                  1
# Main olfactory bulb                                       1
# Name: id, Length: 307, dtype: int64

# %%
counts = (df.groupby('name')['id'].count()
          .sort_values(ascending=False)
          .to_frame().reset_index()
          .rename(columns={"id":"count"}).head(20))

# %%
sns.barplot(data=counts, x='count', y="name")
# Out:
# <AxesSubplot:xlabel='count', ylabel='name'>
